# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
import random
import numpy as np

# %%
def lanzar_2_dados(n):
    acum = 0
    for i in range(n):
        dado1 = random.randint(1,6) 
        dado2 = random.randint(1,6)
        total = dado1 + dado2

        if (total > 7) or total % 2 == 0:
            acum = acum +1

    print(f'probabilidad estimada (en base a {n} repeticiones) de que la puntuación sea mayor a 7 o un número par es: {acum/n}')

lanzar_2_dados(1000)
# Out:
# probabilidad estimada (en base a 1000 repeticiones) de que la puntuación sea mayor a 7 o un número par es: 0.661

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
ball_box = {}

# Crea la cajas con las bolas
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

print(ball_box)
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green'}

# %%
def tomar_bolas(n):

    acum1 = 0
    acum2 = 0

    for i in range(n):
        aleatorio = 0
        rojas = 0
        blancas = 0
        verdes = 0
        for a in range(5):
            
            aleatorio = random.randint(0,59)
            if ball_box[aleatorio] == 'White':
                blancas = blancas + 1
            elif ball_box[aleatorio] == 'Red':
                rojas = rojas + 1
            else:
                verdes = verdes + 1
        
        #print(f'verdes:{verdes}  blancas:{blancas} rojas:{rojas}')

        if (blancas == 3) and (rojas == 2):
            acum1 = acum1 + 1

        if (blancas == 5) or (rojas == 5) or (verdes == 5):
            acum2 = acum2 + 1

    proba1 = acum1 / n
    proba2 = acum2 / n

    print(f'Proba1 = {proba1*100}%')
    print(f'Proba2 = {proba2*100}%')

tomar_bolas(100000)
# Out:
# Proba1 = 0.488%
# Proba2 = 3.511%

# %%
#OTRO METODO - NO LOGRADO

def tomar5bolas(n):

    tiros= [0,0,0,0,0]
    acum1 = 0
    acum2 =0

    for i in range(n):

        tiros = []
        for j in range(5):
            tiros[j] = ball_box[random.randint(1,60)]
        
        print(tiros)
        blancas = tiros.count('White')
        rojas = tiros.count('Red')

        if (blancas == 3) and (rojas == 3):
            acum1 = acum1 + 1 
    
        if (tiros[0] == tiros[1]) and  (tiros[1] == tiros[2]) and  (tiros[2] == tiros[3]) and (tiros[3] == tiros[4]):
            acum2 = acum2 + 1


    proba1 = acum1 / n
    proba2 = acum2 / n

    print(f'Proba1 = {proba1}')
    print(f'Proba2 = {proba2}')


tomar5bolas(1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 33
#      29     print(f'Proba1 = {proba1}')
#      30     print(f'Proba2 = {proba2}')
# ---> 33 tomar5bolas(1)
#
# Cell In[6], line 13, in tomar5bolas(n)
#      11 tiros = []
#      12 for j in range(5):
# ---> 13     tiros[j] = ball_box[random.randint(1,60)]
#      15 print(tiros)
#      16 blancas = tiros.count('White')
#
# IndexError: list assignment index out of range
